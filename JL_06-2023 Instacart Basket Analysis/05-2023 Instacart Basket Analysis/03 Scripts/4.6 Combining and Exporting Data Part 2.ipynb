# %% [markdown]
# # Task 4.6 Part 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Dataframes

# %%
#Define path variable

path = r'C:\Users\HP\Documents\CareerFoundry\Data Immersion\Achievement 4\05-2023 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\HP\\Documents\\CareerFoundry\\Data Immersion\\Achievement 4\\05-2023 Instacart Basket Analysis'

# %%
#Importing products dataset

df_prods =  pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# ## Step 3: Import the orders_products_combined from the pickle file.

# %%
#Import the orders_products_combined pickle file

df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#check file

df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                   2                  8                    NaN         196
# 1                   2                  8                    NaN       14084
# 2                   2                  8                    NaN       12427
# 3                   2                  8                    NaN       26088
# 4                   2                  8                    NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# ## Step 4: Check the shape of the imported dataframe.

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 12)

# %% [markdown]
# ## Step 5: Determine a way to combine the orders_products_combined dataframe with the products dataset.

# %%
#Check columns for df_prods

df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Check columns for dr_ords_prods_combined

df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                   2                  8                    NaN         196
# 1                   2                  8                    NaN       14084
# 2                   2                  8                    NaN       12427
# 3                   2                  8                    NaN       26088
# 4                   2                  8                    NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Drop unneeded column in df_ords_prods_combined: '_merge'

df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
#Check to see if it was dropped properly 

df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                   2                  8                    NaN         196
# 1                   2                  8                    NaN       14084
# 2                   2                  8                    NaN       12427
# 3                   2                  8                    NaN       26088
# 4                   2                  8                    NaN       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# ...

# %%
# Use column 'product_id' as key to merge the dataframes

df_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
#Check df_merged

df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                   2                  8                    NaN         196
# 1                   3                  7                   15.0         196
# 2                   3                 12                   21.0         196
# 3                   4                  7                   29.0         196
# 4                   4                 15                   28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
#Drop 3 unnecessary columns: 'Unnamed: 0.1', 'Unnamed: 0_x', and 'Unnamed: 0_y'

df_merged = df_merged.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0_x', 'Unnamed: 0_y'])

# %%
df_merged.shape
# Out:
# (32404859, 14)

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %% [markdown]
# ## Step 6: Confirm the results of the merge using the merge flag

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ### The value of "both" in the merge column indicates that the key was present in both datasets.

# %% [markdown]
# ## Step 7: Export the dataframe as 'orders_products_merged' in the correct format.

# %%
# Export it in pickle format due to the large amount of rows. 

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
